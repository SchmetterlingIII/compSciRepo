# %% [markdown]
# #Quiz Game
# One of the first challenges set out by Mr S., a more comprehensive introduction into parameter passing.

# %%
from random import randint

def validateInput():
    '''returns a valid menu choice'''
    while True:
        try: 
            userChoice = int(input('Choose an option from the menu: '))
            if userChoice in range(1,7):
                return userChoice
            else:
                print('The value entered is out of range')
        except ValueError:
            print('Only integers are allowed')
            
def validateName():
    '''confinements: can't begin with a number, must be at least 3 characters'''
    while True:
        userName = input("Enter your username: ")
        if len(userName) < 3 or userName[0].isnumeric():
            print("Enter a different username to use")
        else:
            print("Cool beans.")
            improvName = userName[0].upper() + userName[1:].lower()
            return improvName
  
    
def multiplication(userName):
    print(f'Since you chose {difficultyLevel[0]}, you are now in {difficultyLevel[1]} mode. Good luck.\n')
    x=1
    y=1
    if difficultyLevel[0] == 1:
        x = 1
        y = 10
    elif difficultyLevel[0] == 2:
        x = 10
        y = 20
    elif difficultyLevel[0] == 3:
        x = 20
        
    score = 0
    attempts = 0
    print('You are now in the multiplication section')
    while attempts < 10:
        try:
            randNo = [randint(x,y) for randNo in range(2)]
            result = int(input(f'Try and multiply {randNo[0]} to {randNo[1]}: '))
            if result == randNo[0] * randNo[1]:
                print("Correct answer")
                score += 1
            else:
                print("Incorrect. Try this!")
            attempts += 1
        except ValueError:
            print("Only integers are allowed\n")
            
    print(f"{userName}, your score is now {score} and your percentage is {(score/attempts)*100}%.")
    if score < 4:
        print("You can do better")
    elif score < 7:
        print("That's not too bad, not too good")
    else:
        print("Well done!")
        
    redirectionText = "You will now be redirected to the main page."
    hyphen = "_"
    print(f'{redirectionText}\n{hyphen*len(redirectionText)}\n')
    mainPage()


def addition(userName):
    print(f'Since you chose {difficultyLevel[0]}, you are now in {difficultyLevel[1]} mode. Good luck.\n')
    x=1
    y=1
    if difficultyLevel[0] == 1:
        x = 1
        y = 10
    elif difficultyLevel[0] == 2:
        x = 10
        y = 20
    elif difficultyLevel[0] == 3:
        x = 20
        
    score = 0
    attempts = 0
    print('You are now in the addition section')
    while attempts < 10:
        try:
            randNo = [randint(x,y) for randNo in range(2)]
            result = int(input(f'Try and add {randNo[0]} to {randNo[1]}: '))
            if result == randNo[0] + randNo[1]:
                print("Correct answer")
                score += 1
            else:
                print("Incorrect. Try this!")
            attempts += 1
        except ValueError:
            print("Only integers are allowed\n")
            
    print(f"{userName}, your score is now {score} and your percentage is {(score/attempts)*100}%.")
    if score < 4:
        print("You can do better")
    elif score < 7:
        print("That's not too bad, not too good")
    else:
        print("Well done!")
        
    redirectionText = "You will now be redirected to the main page."
    hyphen = "_"
    print(f'{redirectionText}\n{hyphen*len(redirectionText)}\n')
    mainPage()
 

def subtraction(userName):
    print(f'Since you chose {difficultyLevel[0]}, you are now in {difficultyLevel[1]} mode. Good luck.\n')
    x=1
    y=1
    if difficultyLevel[0] == 1:
        x = 1
        y = 10
    elif difficultyLevel[0] == 2:
        x = 10
        y = 20
    elif difficultyLevel[0] == 3:
        x = 20
        
    score = 0
    attempts = 0
    print('You are now in the subtraction section')
    while attempts < 10:
        try:
            randNo = [randint(x,y) for randNo in range(2)]
            result = int(input(f'Try and subtract {randNo[0]} from {randNo[1]}: '))
            if result == randNo[0] - randNo[1]:
                print("Correct answer")
                score += 1
            else:
                print("Incorrect. Try this!")
            attempts += 1
        except ValueError:
            print("Only integers are allowed\n")
            
    print(f"{userName}, your score is now {score} and your percentage is {(score/attempts)*100}%.")
    if score < 4:
        print("You can do better")
    elif score < 7:
        print("That's not too bad, not too good")
    else:
        print("Well done!")
        
    redirectionText = "You will now be redirected to the main page."
    hyphen = "_"
    print(f'{redirectionText}\n{hyphen*len(redirectionText)}\n')
    mainPage()

    
#division -- slightly different to the other three
def division(userName, difficultyLevel):
    print(f'Since you chose {difficultyLevel[0]}, you are now in {difficultyLevel[1]} mode. Good luck.\n')
    x=1
    y=1
    if difficultyLevel[0] == 1:
        x = 1
        y = 10
    elif difficultyLevel[0] == 2:
        x = 10
        y = 20
    elif difficultyLevel[0] == 3:
        x = 20
        y = 100
        
    score = 0
    attempts = 0
    print("You are now in the division section")
    while attempts < 10:
        try:
            randNo = [randint(x,y) for randNo in range(2)]
            #this will ensure we won't get weird float numbers in the result, like with 5/3
            result = int(input(f'What is the result when you divide {randNo[0]*randNo[1]} by {randNo[0]}?\n'))
            if result == randNo[1]:
                print("Correct answer\n")
                score += 1
            else:
                print("Incorrect. Try this!\n")
            attempts += 1
        except ValueError:
            print("Only integers are allowed\n")
    print(f"{userName}, your total is now {score} and your percentage is {(score/attempts)*100}%.")
    if score < 4:
        print("You can do better.")
    elif score < 7:
        print("That's not too bad, not too good")
    else:
        print("Well done!")
        
    print("\nYou will now be redirected to the main page.\n")
    mainPage()
    
def mixed(userName, difficultyLevel):
    print(f'Since you chose {difficultyLevel[0]}, you are now in {difficultyLevel[1]} mode. Good luck.\n')
    x=1
    y=1
    if difficultyLevel[0] == 1:
        x = 1
        y = 10
    elif difficultyLevel[0] == 2:
        x = 10
        y = 20
    elif difficultyLevel[0] == 3:
        x = 20
        y = 100
        
    #now make it work with the rest
    score = 0
    attempts = 0
    while attempts < 10:
        randomSelect = randint(1, 4)
        try:
            attempts += 1
            if randomSelect == 1:
                # Addition
                randNo = [randint(x, y) for _ in range(2)]
                result = int(input(f'Try and add {randNo[0]} to {randNo[1]}: '))
                if result == randNo[0] + randNo[1]:
                    print("Correct answer\n")
                    score += 1
                else:
                    print("Incorrect. Try this!\n")
            elif randomSelect == 2:
                # Multiplication
                randNo = [randint(x, y) for _ in range(2)]
                result = int(input(f'Try and multiply {randNo[0]} by {randNo[1]}: '))
                if result == randNo[0] * randNo[1]:
                    print("Correct answer\n")
                    score += 1
                else:
                    print("Incorrect. Try this!\n")
            elif randomSelect == 3:
                # Subtraction
                randNo = [randint(x, y) for _ in range(2)]
                result = int(input(f'Try and subtract {randNo[0]} from {randNo[1]}: '))
                if result == randNo[1] - randNo[0]:
                    print("Correct answer\n")
                    score += 1
                else:
                    print("Incorrect. Try this!\n")
            elif randomSelect == 4:
                # Division
                randNo = [randint(x, y) for _ in range(2)]
                result = int(input(f'What is the result when you divide {randNo[0] * randNo[1]} by {randNo[0]}? '))
                if result == randNo[1]:
                    print("Correct answer\n")
                    score += 1
                else:
                    print("Incorrect. Try this!\n")
        except ValueError:
            print("Only integers are allowed\n")
    
    print(f"{userName}, your total is now {score} and your percentage is {(score/attempts)*100:.2f}%.")
    if score < 4:
        print("You can do better")
    elif score < 7:
        print("That's not too bad, not too good")
    else:
        print("Well done!")
        
    print("\nYou will now be redirected to the main page.\n")
    return score
    mainPage()
            

    

def menuScreen():
#prints out the program menu
    title = "Welcome to Reuben's Quiz"
    deco = "_"
    menuItems = """
1. Multiplication
2. Addition
3. Subtraction
4. Division
5. Mixed
6. Quit
"""
    print(f'{title}\n{deco*len(title)}\n{menuItems}')
    
def difficultyChooser(): 
    difficultyPresenter = ("There are three difficulty levels:\n1. Easy\n2. Medium\n3. Hard")
    while True:
        try:
            print(difficultyPresenter)
            diffChooser = int(input("Before we start, choose the difficulty of your quiz: "))
            if diffChooser in range(1,4):
                print("You will be redirected...")
                if diffChooser == 1:
                    diffChooser = [1,"easy"]
                elif diffChooser ==2:
                    diffChooser = [2,"medium"]
                elif diffChooser ==3:
                    diffChooser = [3,"hard"]
                return diffChooser
            else:
                print("You're value is outside of range")
        except ValueError:
            print("Enter an integer within the range.\n Try again.")
            



def linesLonger3():
    print()
def linesShorter3():
    print()
def fileStorageSection(score):
    fileStorage = 'fileStorage.txt'
    #read the file and determine whether it is empty or not
    #then add your score and leave a new 
    try:
        with open("fileStorage.txt", "r") as f:
            lines = f.readlines()
            
            #append new scores at the end of the file
            lines.append(f'{score}/n')
            
            #read only the final three scores, if it's more than three
            if len(lines)>3:
                lines = lines[-3:]
                
            with open(fileStorage, "w") as f:
                f.writelines(lines)
                
            #sort the final scores
            sortedScores = sorted(lines)
            print(f'your updated scores are: {sortedScores}')
                    
    except FileNotFoundError:
        print("This file doesn't exist.")
                        
def fileStorageSection1(score):
    fileVariable = 'fileStorage.txt'
    #read the file and determine whether it is empty or not
    #then add your score and leave a new 
    try:
        with open("fileStorage.txt", "r") as f:
            if f.read(1) == "":
                with open("fileStorage.txt", "a") as i:
                    i.write(f'{score}')
            else:
                with open("fileStorage.txt", "a") as i:
                    i.write(f'\n{score}')
        with open("fileStorage.txt", "r") as l:
            variable = l.read()
            print(variable)
            
    
#sort out this code
        with open("fileStorage.txt", "w") as f:
            f.write(str(score))
            ##
        with open("fileStorage.txt", "r") as f:
            scoreData = f.read()
            print("So, your total score for the whole section is:", scoreData)
#the attempting section (and how many attempts there are) of this should occur later

        
        
def mainPage():
    '''in the example of division(userName), it's necessary to reference it here and then in the brackets:
        so that it can later be referenced within this different function; this is parameter passing'''
    #how to implement the difficulty secion without copying and pasting each section with a difficult level
    menuScreen()
    userChoice = validateInput()
    if userChoice == 6:
        print("Goodbye.")
    else:
        userName = validateName()
        difficultyLevel = difficultyChooser()
        while True:
            if userChoice == 1:
                multiplication(userName, difficultyLevel)
                break
            elif userChoice == 2:
                addition(userName, difficultyLevel)
                break
            elif userChoice == 3:
                subtraction(userName, difficultyLevel)
                break
            elif userChoice == 4:
                division(userName, difficultyLevel)
                break
            elif userChoice == 5:
                score = mixed(userName, difficultyLevel)
                fileStorageSection(score)
                break
